# %% [markdown]
# # Decision Tree Regression

# %%
#importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# !conda update seaborn
import seaborn as sns

print('libraries imported')
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following packages will be UPDATED:
#
#     seaborn: 0.8.0-py35h15a2772_0 --> 0.9.0-py35_0
#
# seaborn-0.9.0- 100% |################################| Time: 0:00:00  49.87 MB/s
# libraries imported

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
X = df.iloc[:,1:2].values
y = df.iloc[:,2].values

# %% [markdown]
# ### Modelling

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
y_pred = regressor.predict(X)

# %%
#visualising predictions
plt.scatter(X,y,marker='*')
plt.plot(X, y_pred,color='g')
plt.xlabel('Position Levels')
plt.ylabel('Salaries')
plt.title('Decision Tree Regression')
# Out:
# Text(0.5,1,'Decision Tree Regression')

# %%
# smoothing predictions
x_grid = np.arange(min(X),max(X),0.01).reshape(-1,1)
plt.scatter(X,y)
plt.plot(x_grid,regressor.predict(x_grid))
plt.xlabel('Position Levels')
plt.ylabel('Salaries')
plt.title('Decision Tree Regression')
# Out:
# Text(0.5,1,'Decision Tree Regression')

# %% [markdown]
# ### Metrics

# %%
from sklearn import metrics
print("mean absolute error is", metrics.mean_absolute_error(y,y_pred))
print("mean squared error is", metrics.mean_squared_error(y,y_pred))
print("root mean absolute error is", np.sqrt(metrics.mean_squared_error(y,y_pred)))
# Out:
# mean absolute error is 0.0
# mean squared error is 0.0
# root mean absolute error is 0.0
